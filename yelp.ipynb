# %%
import pandas as pd
import numpy as np

# %%
data_v1 = pd.read_csv("data_v1.csv", dtype = {'ZIPCODE':str, 'PHONE':str, 'CAMIS':str})

# %%
d_10001 = pd.read_csv("10001.csv", dtype = {'biz-phone':str})

# %%
d_10001 = d_10001[['biz-name', 'review-count', 'business-attribute', 'category-str-list', 'secondary-attributes', 'biz-phone']]

# %%
staten_island = pd.read_csv("staten_island.csv", dtype = {'biz-phone':str})

# %%
staten_island = staten_island[['biz-name', 'review-count', 'business-attribute', 'category-str-list', 'secondary-attributes', 'biz-phone']]

# %%
bronx = pd.read_csv("bronx.csv", dtype = {'biz-phone':str})

# %%
bronx = bronx[['biz-name', 'review-count', 'business-attribute', 'category-str-list', 'secondary-attributes', 'biz-phone']]

# %%
d_10013 = pd.read_csv("10013.csv", dtype = {'biz-phone':str})

# %%
d_10013 = d_10013[['biz-name', 'review-count', 'business-attribute', 'category-str-list', 'secondary-attributes', 'biz-phone']]

# %%
mid_east = pd.read_csv("mid_east.csv", dtype = {'biz-phone':str})

# %%
mid_east = mid_east[['biz-name', 'review-count', 'business-attribute', 'category-str-list', 'secondary-attributes', 'biz-phone']]

# %%
brky = pd.read_csv("brky.csv", dtype = {'biz-phone':str})

# %%
brky = brky[['biz-name', 'review-count', 'business-attribute', 'category-str-list', 'secondary-attributes', 'biz-phone']]

# %%
queens_34 = pd.read_csv("queens_34.csv", dtype = {'biz-phone':str})

# %%
queens_34 = queens_34[['biz-name', 'review-count', 'business-attribute', 'category-str-list', 'secondary-attributes', 'biz-phone']]

# %%
queens_up = pd.read_csv("queens_up.csv", dtype = {'biz-phone':str})
queens_up = queens_up[['biz-name', 'review-count', 'business-attribute', 'category-str-list', 'secondary-attributes', 'biz-phone']]

# %%
queens_down = pd.read_csv("queens_down.csv", dtype = {'biz-phone':str})
queens_down = queens_down[['biz-name', 'review-count', 'business-attribute', 'category-str-list', 'secondary-attributes', 'biz-phone']]

# %%
up_west = pd.read_csv("up_west.csv", dtype = {'biz-phone':str})
up_west = up_west[['biz-name', 'review-count', 'business-attribute', 'category-str-list', 'secondary-attributes', 'biz-phone']]

# %%
harlem = pd.read_csv("harlem.csv", dtype = {'biz-phone':str})
harlem = harlem[['biz-name', 'review-count', 'business-attribute', 'category-str-list', 'secondary-attributes', 'biz-phone']]

# %%
d10004 = pd.read_csv("10004.csv", dtype = {'biz-phone':str})
d10004 = d10004[['biz-name', 'review-count', 'business-attribute', 'category-str-list', 'secondary-attributes', 'biz-phone']]

# %%
d10012 = pd.read_csv("10012.csv", dtype = {'biz-phone':str})
d10012 = d10012[['biz-name', 'review-count', 'business-attribute', 'category-str-list', 'secondary-attributes', 'biz-phone']]

# %%
up_east = pd.read_csv("up_east.csv", dtype = {'biz-phone':str})
up_east = up_east[['biz-name', 'review-count', 'business-attribute', 'category-str-list', 'secondary-attributes', 'biz-phone']]

# %%
hell = pd.read_csv("hell.csv", dtype = {'biz-phone':str})
hell = hell[['biz-name', 'review-count', 'business-attribute', 'category-str-list', 'secondary-attributes', 'biz-phone']]

# %%
d10011 = pd.read_csv("10011.csv", dtype = {'biz-phone':str})
d10011 = d10011[['biz-name', 'review-count', 'business-attribute', 'category-str-list', 'secondary-attributes', 'biz-phone']]

# %%
yelp = d_10001

yelp = yelp.append(staten_island, ignore_index=True)

yelp = yelp.append(bronx, ignore_index=True)

yelp = yelp.append(d_10013, ignore_index=True)

yelp = yelp.append(mid_east, ignore_index=True)

yelp = yelp.append(brky, ignore_index=True)

yelp = yelp.append(queens_34, ignore_index=True)

yelp = yelp.append(queens_up, ignore_index=True)

yelp = yelp.append(queens_down, ignore_index=True)

yelp = yelp.append(up_west, ignore_index=True)

yelp = yelp.append(harlem, ignore_index=True)

yelp = yelp.append(d10004, ignore_index=True)

yelp = yelp.append(d10012, ignore_index=True)

yelp = yelp.append(up_east, ignore_index=True)

yelp = yelp.append(hell, ignore_index=True)

yelp = yelp.append(d10011, ignore_index=True)

# %%
yelp['zip'] = yelp['secondary-attributes'].str.slice(-5)

# %%
yelp['phone'] = yelp['biz-phone'].str.slice(1,4) + yelp['biz-phone'].str.slice(6,9) + yelp['biz-phone'].str.slice(10,14)

# %%
yelp['price'] = yelp['business-attribute'].str.len()

# %%
yelp['review'] = yelp['review-count'].str.extract('(\d+)')
# Out:
# /Users/jiehuanhuang/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   if __name__ == '__main__':

# %%
yelp['name'] = yelp['biz-name'].str.upper()

# %%
yelp = yelp.drop(['biz-name', 'review-count', 'business-attribute', 'biz-phone'], axis=1)

# %%
yelp.shape
# Out:
# (15252, 7)

# %%
yelp_dup = yelp.drop_duplicates(subset=['phone', 'name'])

# %%
yelp_dup.shape
# Out:
# (10071, 7)

# %%
data_yelp = pd.merge(data_v1, yelp, left_on=['PHONE'], right_on= ['phone'])

# %%
data_yelp2 = pd.merge(data_v1, yelp, left_on=['DBA', 'ZIPCODE'], right_on= ['name', 'zip'])

# %%
data_yelp_m = data_yelp.append(data_yelp2, ignore_index=True)

# %%
data_yelp_dup = data_yelp_m.drop_duplicates(subset=['phone', 'name'])

# %%
data_yelp_dup.groupby(['target']).count()
# Out:
#         Unnamed: 0  CAMIS   DBA  PHONE  BORO  BUILDING  STREET  ZIPCODE  \
# target
# 0             4287   4287  4287   4287  4287      4287    4287     4287
# 1             3153   3153  3153   3153  3153      3153    3153     3153
#
#         CUISINE DESCRIPTION  latitude  ...   longitude_fillna  lat_scal  \
# target                                 ...
# 0                      4287      3937  ...               4287      4287
# 1                      3153      2862  ...               3153      3153
#
#         lon_scal  category-str-list  secondary-attributes   zip  phone  price  \
# target
# 0           4287               3452                  4251  4251   4255   4129
# 1           3153               2462                  3139  3139   3137   3045
#
#         review  name
# target
# 0         4280  4287
# 1         3149  3153
#
# [2 rows x 22 columns]

# %%
data_v2 = data_yelp_dup.drop(['Unnamed: 0', 'category-str-list', 'secondary-attributes', 'name', 'zip', 'phone'], axis=1)

# %%
data_v2.loc[data_v2['price'].isnull(), 'price']= data_v2['price'].mean()

# %%
data_v2.loc[data_v2['review'].isnull(), 'review']= 0

# %%
data_v2['review'] = data_v2['review'].astype('str').astype('int16')

# %%
data_v2.loc[data_v2['review']==0, 'review']= data_v2.loc[data_v2['review']!=0, 'review'].mean()

# %%
data_v2.groupby(['target']).count()
# Out:
#         CAMIS   DBA  PHONE  BORO  BUILDING  STREET  ZIPCODE  \
# target
# 0        4287  4287   4287  4287      4287    4287     4287
# 1        3153  3153   3153  3153      3153    3153     3153
#
#         CUISINE DESCRIPTION  latitude  longitude  latitude_fillna  \
# target
# 0                      4287      3937       3937             4287
# 1                      3153      2862       2862             3153
#
#         longitude_fillna  lat_scal  lon_scal  price  review
# target
# 0                   4287      4287      4287   4287    4287
# 1                   3153      3153      3153   3153    3153

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# %%
vars_fscore = f_classif(data_v2[['lat_scal', 'lon_scal','price', 'review']], data_v2['target'])[0]

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.title("Feature engineering potential impact")
plt.bar(range(4), vars_fscore, color="green", align="center")
plt.xticks(range(4), ['lat_scal', 'lon_scal','price', 'review'], rotation=90)
plt.show()

# %%
import geopandas as gpd
from shapely.geometry import Point
import urllib

# %%
districts = gpd.read_file("Census.GeoJSON")

# %%
zip_m = data_v1.groupby(['ZIPCODE'])[['target']].mean()

# %%
zip_mean = zip_m['target'].to_dict()

# %%
data_v1['zip_mean'] = data_v1['ZIPCODE'].map(lambda x: zip_mean[x])

# %%
def make_point(row):
    return Point(row.longitude_fillna, row.latitude_fillna)

points = data_v1.apply(make_point, axis=1)

map1 = gpd.GeoDataFrame(data_v1, geometry=points)

# %%
map1.plot(figsize=(15,15), column='zip_mean', cmap='seismic', marker='o', markersize=0.8)
